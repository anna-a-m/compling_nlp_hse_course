# %% [markdown]
# # Домашнее задание № 3. Исправление опечаток

# %% [markdown]
# ## 1. Доп. ранжирование по вероятности (3 балла)

# %% [markdown]
# Дополните get_closest_hybrid_match в семинаре так, чтобы из кандидатов с одинаковым расстоянием редактирования выбиралось наиболее вероятное.

# %%
import textdistance
import re
import numpy as np
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity, cosine_distances

# %% [markdown]
# Немного изменим предобработку корпуса, убрав из него символы ударения и добавив в токенизацию слова с дефисом

# %%
corpus = open('data/wiki_data.txt', encoding='utf8').read()
corpus = re.sub(chr(769), '', corpus)
vocab = Counter(re.findall('\w+-\w+|\w+', corpus.lower()))
N = sum(vocab.values())

# %% [markdown]
# Добавим все необходимые функции из ноутбука с пары. Несколько изменим функцию `get_closest_match_with_metric`: добавим после метрики расчет вероятности слова для более удобной дальнейшей фильтрации.
#
# Для сравнения исправления опечаток скопируем функцию `get_closest_hybrid_match` в `pr_get_closest_hybrid_match`.
#
# В функции `get_closest_hybrid_match` добавим отбор кандидатов по вероятности следующим образом:
#
#     пройдемся по списку с полученными метриками,
#     добавим в новый список кандидата с его метрикой и вероятностью, если
#         в списке нет слова с такой же метрикой И его вероятность выше, чем у слова с такой же метрикой кандидата в списке

# %%
def P(word, N=N):
    return vocab[word] / N

def predict_mistaken(word, vocab):
    return 0 if word in vocab else 1

def get_closest_match_with_metric(text, lookup, topn=20, metric=textdistance.levenshtein):
    # Counter можно использовать и с не целыми числами
    similarities = Counter()
    
    for word in lookup:
        similarities[word] = (metric.normalized_similarity(text, word), P(word))
    
    return similarities.most_common(topn)

def get_closest_match_vec(text, X, vec, topn=20):
    v = vec.transform([text])
    
    similarities = cosine_distances(v, X)[0]
    topn = similarities.argsort()[:topn] 
    
    return [(id2word[top], similarities[top]) for top in topn]
 
def pr_get_closest_hybrid_match(text, X, vec, topn=3, metric=textdistance.damerau_levenshtein):
    candidates = get_closest_match_vec(text, X, vec, topn*4)
    lookup = [cand[0] for cand in candidates]
    closest = get_closest_match_with_metric(text, lookup, topn, metric=metric)
    
    return closest

def get_closest_hybrid_match(text, X, vec, topn=3, metric=textdistance.damerau_levenshtein):
    candidates = get_closest_match_vec(text, X, vec, topn*4)
    lookup = [cand[0] for cand in candidates]
    closest_metric_pr = get_closest_match_with_metric(text, lookup, topn, metric=metric)
    
    closest = []
    for w, m in closest_metric_pr:
        if closest:
            if m[0] == closest[-1][1][0]:
                if m[1] > closest[-1][1][1]:
                    closest.pop()
                    closest.append((w, m))
            else:
                closest.append((w, m))
        else:
            closest.append((w, m))
    
    return closest

# %%
word2id = list(vocab.keys())
id2word = {i:word for i, word in enumerate(vocab)}

vec = CountVectorizer(analyzer='char', ngram_range=(1,1))
X = vec.fit_transform(vocab)

# %%
get_closest_match_with_metric('шде-то', vocab, topn=5)
# Out:
# [('где-то', (0.8333333333333334, 1.0466768503716196e-05)),
#  ('чье-то', (0.6666666666666667, 3.949723963666489e-07)),
#  ('детто', (0.6666666666666667, 1.9748619818332446e-07)),
#  ('де-чо', (0.6666666666666667, 1.9748619818332446e-07)),
#  ('удето', (0.6666666666666667, 1.9748619818332446e-07))]

# %%
get_closest_hybrid_match('колмпания', X, vec)
# Out:
# [('компания', (0.8888888888888888, 0.0001840571367068584)),
#  ('компаниям', (0.7777777777777778, 4.542182558216463e-06)),
#  ('кинокомпания', (0.6666666666666667, 5.924585945499734e-07))]

# %% [markdown]
# Пример применения функции для слова с несколькими кандидатами с одинаковой метрикой

# %%
pr_get_closest_hybrid_match('ромашк', X, vec)
# Out:
# [('ромашка', (0.8571428571428572, 2.172348180016569e-06)),
#  ('ромашки', (0.8571428571428572, 3.949723963666489e-07)),
#  ('ромашке', (0.8571428571428572, 1.9748619818332446e-07))]

# %%
get_closest_hybrid_match('ромашк', X, vec)
# Out:
# [('ромашка', (0.8571428571428572, 2.172348180016569e-06))]

# %%
3.949723963666489e-07 < 2.172348180016569e-06
# Out:
# True

# %% [markdown]
# ## 2.  Symspell (5 баллов)

# %% [markdown]
# Реализуйте алгоритм Symspell. Он похож на алгоритм Норвига, но проще и быстрее. Там к словам применяется только одна операция - удаление символа. Описание алгоритма по шагам:
#
# 1) Составляется словарь правильных слов
# 2) На основе словаря правильных слов составляется словарь удалений - для каждого правильного слова создаются все варианты удалений и создается словарь, где ключ - слово с удалением, а значение - правильное слово
# 3) Для выбора исправления для слова с опечаткой генерируются все варианты удаления, из них выбираются те, что есть в словаре удалений, построенного на шаге 2. Слово с опечаткой заменяется на правильное слово, соответствующее варианту удаления
# 4) Если в словаре удалений есть несколько вариантов, то выбирается удаление, которому соответствует наиболее вероятное правильное слово
#
#
# Оцените качество полученного алгоритма теми же тремя метриками.

# %%
corpus = open('data/wiki_data.txt', encoding='utf8').read()
corpus = re.sub(chr(769), '', corpus)
vocab = Counter(re.findall('\w+-\w+|\w+', corpus.lower()))
N = sum(vocab.values())

# %% [markdown]
# Заводим функцию, которая генерирует удаления (позаимствована из ноутбука с пары)
#
# Добавляем в словарь удалений только не пустые строчки (потому что удаление, например, для предлога *в* - ""). Также убираем лишние знаки пунктуации, если попадаются, и цифры

# %%
def generate_deletes(word):    
    splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]
    return [L + R[1:] for L, R in splits if R]

deletes_vocab = {}
for v in vocab:
    for w in generate_deletes(v):
        if w and not w.isdigit():
            if not w in deletes_vocab:
                deletes_vocab[w] = [v]
            else:
                deletes_vocab[w].append(v)

# %% [markdown]
# Получившийся словарь удалений:
#
# {удаление: варианты исправления списком}

# %%
deletes_vocab
# Out:
# {'овостройка': ['новостройка'],
#  'нвостройка': ['новостройка'],
#  'ноостройка': ['новостройка'],
#  'новстройка': ['новостройка'],
#  'новотройка': ['новостройка'],
#  'новосройка': ['новостройка'],
#  'новостойка': ['новостройка'],
#  'новострйка': ['новостройка'],
#  'новострока': ['новостройка'],
#  'новостройа': ['новостройка'],
#  'новостройк': ['новостройка', 'новостройки'],
#  'ижегородская': ['нижегородская'],
#  'нжегородская': ['нижегородская'],
#  'ниегородская': ['нижегородская'],
#  'нижгородская': ['нижегородская'],
#  'нижеородская': ['нижегородская'],
#  'нижегродская': ['нижегородская'],
#  'нижегоодская': ['нижегородская'],
#  'нижегордская': ['нижегородская'],
#  'нижегороская': ['нижегородская'],
#  'нижегородкая': ['нижегородская'],
#  'нижегородсая': ['нижегородская'],
#  'нижегородскя': ['нижегородская'],
#  'нижегородска': ['нижегородская'],
#  'бласть': ['область'],
#  'оласть': ['область'],
#  'обасть': ['область'],
#  'облсть': ['область'],
#  'облать': ['область'],
#  'облась': ['область'],
#  'област': ['область', 'области'],
#  'ельский': ['сельский', 'бельский', 'йельский', 'вельский'],
#  'сльский': ['сельский', 'сальский'],
#  'сеьский': ['сельский'],
#  'селский': ['сельский'],
#  'селький': ['сельский'],
#  'сельсий': ['сельский'],
#  'сельскй': ['сельский', 'сельской'],
#  'сельски': ['сельский', 'сельских', 'сельские', 'сельским'],
#  'осёлок': ['посёлок'],
#  'псёлок': ['посёлок'],
#  'поёлок': ['посёлок'],
#  'послок': ['посёлок', 'поселок', 'посылок'],
#  'посёок': ['посёлок'],
#  'посёлк': ['посёлок', 'посёлке', 'посёлка', 'посёлку', 'посёлки'],
#  'посёло': ['посёлок'],
#  'ивеевском': ['дивеевском'],
#  'двеевском': ['дивеевском'],
#  'диеевском': ['дивеевском'],
#  'дивевском': ['дивеевском', 'дивеевском'],
#  'дивееском': ['дивеевском'],
#  'дивеевком': ['дивеевском'],
#  'дивеевсом': ['дивеевском'],
#  'дивеевскм': ['дивеевском', 'дивеевским'],
#  'дивеевско': ['дивеевском'],
#  'айоне': ['районе'],
#  'рйоне': ['районе'],
#  'раоне': ['районе', 'краоне', 'рамоне'],
#  'райне': ['районе', 'крайне', 'райнер', 'райане', 'грайне'],
#  'райое': ['районе'],
#  'район': ['районе',
#   'района',
#   'районы',
#   'району',
#   'районо',
#   'брайон',
#   'раймон'],
#  'ижегородской': ['нижегородской'],
#  'нжегородской': ['нижегородской'],
#  'ниегородской': ['нижегородской'],
#  'нижгородской': ['нижегородской'],
#  'нижеородской': ['нижегородской'],
#  'нижегродской': ['нижегородской'],
#  'нижегоодской': ['нижегородской'],
#  'нижегордской': ['нижегородской'],
#  'нижегороской': ['нижегородской'],
#  'нижегородкой': ['нижегородской'],
#  'нижегородсой': ['нижегородской'],
#  'нижегородскй': ['нижегородской', 'нижегородский'],
#  'нижегородско': ['нижегородской', 'нижегородском', 'нижегородское'],
#  'бласти': ['области'],
#  'оласти': ['области'],
#  'обасти': ['области'],
#  'облсти': ['области'],
#  'облати': ['области', 'облатки'],
#  'обласи': ['области'],
#  'ходит': ['входит', 'ходить', 'уходит', 'сходит'],
#  'водит': ['входит', 'сводит', 'вводит', 'вводит', 'уводит', 'водить'],
#  'вхдит': ['входит'],
#  'вхоит': ['входит'],
#  'входт': ['входит', 'входят'],
#  'входи': ['входит', 'входил', 'выходи'],
#  'остав': ['состав', 'отстав', 'постав', 'достав'],
#  'сстав': ['состав'],
#  'сотав': ['состав'],
#  'сосав': ['состав', 'сослав'],
#  'соств': ['состав'],
#  'соста': ['состав'],
#  'атисского': ['сатисского'],
#  'стисского': ['сатисского'],
#  'саисского': ['сатисского'],
#  'сатсского': ['сатисского'],
#  'сатиского': ['сатисского', 'сатисского', 'сатинского'],
#  'сатиссого': ['сатисского'],
#  'сатисскго': ['сатисского'],
#  'сатисскоо': ['сатисского'],
#  'сатисског': ['сатисского'],
#  'ельсовета': ['сельсовета'],
#  'сльсовета': ['сельсовета'],
#  'сеьсовета': ['сельсовета'],
#  'селсовета': ['сельсовета'],
#  'сельовета': ['сельсовета'],
#  'сельсвета': ['сельсовета'],
#  'сельсоета': ['сельсовета'],
#  'сельсовта': ['сельсовета'],
#  'сельсовеа': ['сельсовета'],
#  'сельсовет': ['сельсовета', 'сельсовету', 'сельсоветы', 'сельсовете'],
#  'асположен': ['расположен'],
#  'рсположен': ['расположен'],
#  'раположен': ['расположен'],
#  'расоложен': ['расположен'],
#  'распложен': ['расположен'],
#  'распоожен': ['расположен'],
#  'располжен': ['расположен'],
#  'располоен': ['расположен'],
#  'расположн': ['расположен'],
#  'расположе': ['расположен'],
#  'м': ['км',
#   'мл',
#   'им',
#   'нм',
#   'м²',
#   'м³',
#   'мм',
#   'мм',
#   'ом',
#   'мо',
#   'мы',
#   'см',
#   'ям',
#   'мя',
#   'ум',
#   'му',
#   'эм',
#   'ма',
#   'мб',
#   'мг',
#   'мх',
#   'мк',
#   'мф',
#   'мт',
#   'мз',
#   'тм',
#   'м3',
#   'мд',
#   'мн',
#   'м1',
#   'ми',
#   'ам',
#   'мп',
#   'мс',
#   'чм',
#   'ме',
#   'м2',
#   'мц',
#   'рм',
#   'мæ',
#   'м7',
#   'µм',
#   'м5',
#   'мэ',
#   'дм',
#   'мр',
#   'мъ',
#   'мв',
#   'вм',
#   'гм',
#   'мю',
#   'μм',
#   'м0',
#   'пм',
#   '3м',
#   '2м',
#   'мs',
#   'мч',
#   'жм',
#   'ем'],
#  'к': ['км',
#   'ко',
#   'кг',
#   'кн',
#   'кв',
#   'цк',
#   'гк',
#   'рк',
#   'кп',
#   'ук',
#   'ок',
#   'кт',
#   'кс',
#   'ку',
#   'кр',
#   'кз',
#   'ск',
#   'ки',
#   'фк',
#   'тк',
#   'ак',
#   'мк',
#   'кб',
#   'кg',
#   'кл',
#   'ик',
#   'к1',
#   'хк',
#   'к2',
#   'дк',
#   'ка',
#   'чк',
#   'ке',
#   'пк',
#   'к8',
#   'к7',
#   'жк',
#   'як',
#   'нк',
#   'кш',
#   'кк',
#   'кк',
#   'ек',
#   'кф',
#   'эк',
#   'бк',
#   'кд',
#   '4к',
#   'къ',
#   'вк',
#   'к3',
#   'лк',
#   'кю',
#   'кё',
#   'к5',
#   '5к',
#   'кц'],
#  'гу': ['югу',
#   'гуд',
#   'мгу',
#   'гуп',
#   'гоу',
#   'губ',
#   'фгу',
#   'тгу',
#   'гпу',
#   'кгу',
#   'лгу',
#   'гус',
#   'гбу',
#   'гук',
#   'гун',
#   'чгу',
#   'гуз',
#   'пгу',
#   'гуй',
#   'дгу',
#   'ягу',
#   'вгу',
#   'гур',
#   'гул',
#   'гут',
#   'гау',
#   'ргу',
#   'гру',
#   'бгу',
#   'гму',
#   'огу',
#   'гуя',
#   'агу',
#   'гту',
#   'гуу',
#   'гуу',
#   'нгу',
#   'гуи',
#   'гэу',
#   'гну'],
#  'юу': ['югу', 'юну', 'юту', 'юфу', 'юру'],
#  'юг': ['югу', 'юге', 'юга', 'юго', 'юнг', 'югв', 'югъ'],
#  'т': ['от',
#   'то',
#   'те',
#   'ст',
#   'ту',
#   'тд',
#   'тц',
#   'тв',
#   'ты',
#   'та',
#   'ти',
#   'ат',
#   'шт',
#   'кт',
#   'ют',
#   'тк',
#   'мт',
#   'пт',
#   'тм',
#   'тс',
#   'цт',
#   'oт',
#   'вт',
#   'чт',
#   'эт',
#   'рт',
#   'т2',
#   'тж',
#   'тh',
#   'т5',
#   'тe',
#   'т3',
#   'т4',
#   'тп',
#   'ят',
#   'тэ',
#   'тт',
#   'тт',
#   'тр',
#   'тч',
#   'бт',
#   '4т',
#   'тл',
#   'ит',
#   '8т',
#   '9т',
#   'тб',
#   'тг',
#   'ыт',
#   'mт'],
#  'о': ['от',
#   'по',
#   'но',
#   'во',
#   'до',
#   'он',
#   'то',
#   'со',
#   'об',
#   'ко',
#   'ро',
#   'ом',
#   'мо',
#   'хо',
#   'ок',
#   'бо',
#   'го',
#   'ао',
#   'ов',
#   'ос',
#   'ош',
#   'оf',
#   'шо',
#   'оф',
#   'оп',
#   'ор',
#   'оз',
#   'ло',
#   'фо',
#   'чо',
#   'од',
#   'aо',
#   'оц',
#   'яо',
#   'о2',
#   'уо',
#   'ох',
#   'ио',
#   'ол',
#   'ой',
#   'ео',
#   'зо',
#   'ог',
#   'оо',
#   'оо',
#   'nо',
#   'юо',
#   'цо',
#   'оу',
#   'оя',
#   'йо',
#   'ои',
#   'жо'],
#  'ела': ['села',
#   'дела',
#   'тела',
#   'бела',
#   'вела',
#   'мела',
#   'пела',
#   'чела',
#   'цела',
#   'елан',
#   'гела',
#   'елга',
#   'есла',
#   'кела'],
#  'сла': ['села',
#   'сёла',
#   'сала',
#   'сила',
#   'осла',
#   'асла',
#   'слаб',
#   'сола',
#   'слав',
#   'сула',
#   'слай',
#   'исла',
#   'есла',
#   'слау'],
#  'сеа': ['села',
#   'сена',
#   'сета',
#   'сева',
#   'сера',
#   'сеча',
#   'сеща',
#   'сеза',
#   'себа',
#   'сека'],
#  'сел': ['села',
#   'село',
#   'селе',
#   'селу',
#   'спел',
#   'съел',
#   'сеул',
#   'счел',
#   'ясел',
#   'селя',
#   'селю',
#   'осел',
#   'свел',
#   'сели',
#   'сдел',
#   'смел',
#   'стел',
#   'селф',
#   'сель',
#   'псел'],
#  'ивеева': ['дивеева'],
#  'двеева': ['дивеева'],
#  'диеева': ['дивеева'],
#  'дивева': ['дивеева', 'дивеева'],
#  'дивееа': ['дивеева'],
#  'дивеев': ['дивеева', 'дивеево', 'дивееве', 'дивееву'],
#  'ападу': ['западу'],
#  'зпаду': ['западу'],
#  'зааду': ['западу', 'засаду'],
#  'запду': ['западу'],
#  'запау': ['западу', 'запаху', 'запасу'],
#  'запад': ['западу', 'западе', 'запада'],
#  'орода': ['города', 'борода', 'порода'],
#  'грода': ['города'],
#  'гоода': ['города', 'голода'],
#  'горда': ['города', 'гордая'],
#  'гороа': ['города', 'гороха', 'гороса'],
#  'город': ['города', 'городе', 'городу', 'огород', 'городъ'],
#  'арова': ['сарова',
#   'жарова',
#   'аврова',
#   'аровас',
#   'дарова',
#   'шарова',
#   'нарова'],
#  'срова': ['сарова', 'скрова', 'серова', 'сурова'],
#  'саова': ['сарова', 'салова'],
#  'сарва': ['сарова'],
#  'сароа': ['сарова', 'сароса', 'сарота'],
#  'саров': ['сарова', 'сарову', 'старов', 'сарове'],
#  'а': ['на',
#   'за',
#   'ан',
#   'га',
#   'да',
#   'аи',
#   'ах',
#   'та',
#   'ай',
#   'ат',
#   'ао',
#   'ра',
#   'ма',
#   'ау',
#   'аl',
#   'ад',
#   'ла',
#   'са',
#   '8а',
#   'аг',
#   'ак',
#   'уа',
#   'ва',
#   'аа',
#   'аа',
#   'hа',
#   'ав',
#   'а4',
#   'а7',
#   'аb',
#   'а8',
#   '9а',
#   '5а',
#   '6а',
#   '1а',
#   'ам',
#   'ас',
#   'ар',
#   'ха',
#   'ка',
#   'аҡ',
#   'аң',
#   '2а',
#   '4а',
#   'аз',
#   'ча',
#   'а6',
#   'а5',
#   'ал',
#   'па',
#   'ап',
#   'аэ',
#   'яа',
#   '7а',
#   'ша',
#   'ща',
#   '3а',
#   'ба',
#   'фа',
#   'йа',
#   'аж',
#   'dа',
#   'а2',
#   'а3',
#   'иа',
#   'а1',
#   'aа',
#   'ая'],
#  'н': ['на',
#   'не',
#   'но',
#   'он',
#   'ни',
#   'кн',
#   'нм',
#   'ну',
#   'нн',
#   'нн',
#   'ан',
#   'нс',
#   'ян',
#   'ин',
#   'ён',
#   'ен',
#   'нa',
#   'рн',
#   'ню',
#   'эн',
#   'нв',
#   'мн',
#   'пн',
#   'юн',
#   'ун',
#   'нп',
#   'дн',
#   'нк',
#   'нр',
#   'ні',
#   'н3',
#   'фн',
#   'ын',
#   'aн',
#   'сн',
#   'нг',
#   'нф',
#   'н1',
#   'нэ'],
#  'равом': ['правом', 'равном', 'нравом'],
#  'павом': ['правом', 'павлом'],
#  'првом': ['правом', 'первом'],
#  'праом': ['правом', 'прахом'],
#  'правм': ['правом', 'правам', 'правым'],
#  'право': ['правом', 'правой', 'вправо', 'правое', 'правок'],
#  'ерегу': ['берегу'],
#  'брегу': ['берегу'],
#  'беегу': ['берегу'],
#  'бергу': ['берегу'],
#  'береу': ['берегу'],
#  'берег': ['берегу', 'берега', 'оберег', 'береги'],
#  'еки': ['реки',
#   'шеки',
#   'зеки',
#   'веки',
#   'щеки',
#   'беки',
#   'елки',
#   'чеки',
#   'леки'],
#  'рки': ['реки', 'руки', 'арки', 'рики', 'раки', 'орки', 'юрки', 'ркин'],
#  'реи': ['реки',
#   'речи',
#   'реви',
#   'реми',
#   'режи',
#   'рени',
#   'рети',
#   'реши',
#   'фреи',
#   'реди',
#   'греи'],
#  'рек': ['реки',
#   'роек',
#   'река',
#   'реке',
#   'реку',
#   'брек',
#   'трек',
#   'рекс',
#   'грек',
#   'шрек',
#   'рекѣ',
#   'реек',
#   'реек',
#   'ирек'],
#  'ичкинза': ['вичкинза'],
#  'вчкинза': ['вичкинза'],
#  'викинза': ['вичкинза'],
#  'вичинза': ['вичкинза'],
#  'вичкнза': ['вичкинза'],
#  'вичкиза': ['вичкинза'],
#  'вичкина': ['вичкинза'],
#  'вичкинз': ['вичкинза', 'вичкинзы', 'вичкинзу'],
#  'равый': ['правый', 'бравый', 'равный'],
#  'павый': ['правый'],
#  'првый': ['правый', 'первый'],
#  'праый': ['правый'],
#  'правй': ['правый', 'правой'],
#  'правы': ['правый',
#   'управы',
#   'правым',
#   'правые',
#   'правды',
#   'правых',
#   'справы',
#   'оправы'],
#  'риток': ['приток'],
#  'питок': ['приток', 'плиток'],
#  'прток': ['приток', 'проток'],
#  'приок': ['приток'],
#  'притк': ['приток'],
#  'прито': ['приток', 'притом', 'притон', 'прието'],
#  'атис': ['сатис', 'матис', 'аутис'],
#  'стис': ['сатис', 'стикс', 'юстис', 'стирс'],
#  'саис': ['сатис'],
#  'сатс': ['сатис'],
#  'сати': ['сатис', 'сарти', 'сатир', 'санти', 'стати', 'осати', 'саути'],
#  'кружён': ['окружён'],
#  'оружён': ['окружён'],
#  'окужён': ['окружён'],
#  'окржён': ['окружён'],
#  'окруён': ['окружён'],
#  'окружн': ['окружён', 'окружен'],
#  'окружё': ['окружён'],
#  'мешанными': ['смешанными'],
#  'сешанными': ['смешанными'],
#  'смшанными': ['смешанными'],
#  'смеанными': ['смешанными'],
#  'смешнными': ['смешанными'],
#  'смешаными': ['смешанными', 'смешанными'],
#  'смешаннми': ['смешанными'],
#  'смешанныи': ['смешанными'],
#  'смешанным': ['смешанными'],
#  'есами': ['лесами', 'весами'],
#  'лсами': ['лесами', 'лисами'],
#  'леами': ['лесами', 'летами'],
#  'лесми': ['лесами'],
#  'лесаи': ['лесами'],
#  'лесам': ['лесами', 'лесамы'],
#  'оединён': ['соединён'],
#  'сединён': ['соединён'],
#  'содинён': ['соединён'],
#  'соеинён': ['соединён'],
#  'соеднён': ['соединён'],
#  'соедиён': ['соединён'],
#  'соединн': ['соединён', 'соединен'],
#  'соединё': ['соединён'],
#  'сфальтовой': ['асфальтовой'],
#  'афальтовой': ['асфальтовой'],
#  'асальтовой': ['асфальтовой'],
#  'асфльтовой': ['асфальтовой'],
#  'асфаьтовой': ['асфальтовой'],
#  'асфалтовой': ['асфальтовой'],
#  'асфальовой': ['асфальтовой'],
#  'асфальтвой': ['асфальтовой'],
#  'асфальтоой': ['асфальтовой'],
#  'асфальтовй': ['асфальтовой', 'асфальтовый'],
#  'асфальтово': ['асфальтовой', 'асфальтовое'],
#  'орогой': ['дорогой'],
#  'дрогой': ['дорогой'],
#  'доогой': ['дорогой'],
#  'доргой': ['дорогой'],
#  'дороой': ['дорогой'],
#  'дорогй': ['дорогой'],
#  'дорого': ['дорогой', 'доброго', 'дорогое', 'дорогом'],
#  'осёлком': ['посёлком'],
#  'псёлком': ['посёлком'],
#  'поёлком': ['посёлком'],
#  'послком': ['посёлком', 'поселком'],
#  'посёком': ['посёлком'],
#  'посёлом': ['посёлком'],
#  'посёлкм': ['посёлком', 'посёлкам'],
#  'посёлко': ['посёлком', 'посёлков'],
#  'ыгановка': ['цыгановка'],
#  'цгановка': ['цыгановка'],
#  'цыановка': ['цыгановка'],
#  'цыгновка': ['цыгановка'],
#  'цыгаовка': ['цыгановка'],
#  'цыганвка': ['цыгановка'],
#  'цыганока': ['цыгановка'],
#  'цыганова': ['цыгановка', 'цыганкова'],
#  'цыгановк': ['цыгановка', 'цыгановке', 'цыгановки', 'цыгановку'],
#  'рунтовыми': ['грунтовыми'],
#  'гунтовыми': ['грунтовыми'],
#  'грнтовыми': ['грунтовыми'],
#  'грутовыми': ['грунтовыми'],
#  'груновыми': ['грунтовыми'],
#  'грунтвыми': ['грунтовыми'],
#  'грунтоыми': ['грунтовыми'],
#  'грунтовми': ['грунтовыми'],
#  'грунтовыи': ['грунтовыми'],
#  'грунтовым': ['грунтовыми'],
#  'росёлочными': ['просёлочными'],
#  'посёлочными': ['просёлочными'],
#  'прсёлочными': ['просёлочными'],
#  'проёлочными': ['просёлочными'],
#  'прослочными': ['просёлочными'],
#  'просёочными': ['просёлочными'],
#  'просёлчными': ['просёлочными'],
#  'просёлоными': ['просёлочными'],
#  'просёлочыми': ['просёлочными'],
#  'просёлочнми': ['просёлочными'],
#  'просёлочныи': ['просёлочными'],
#  'просёлочным': ['просёлочными'],
#  'орогами': ['дорогами', 'порогами', 'отрогами'],
#  'дрогами': ['дорогами'],
#  'доогами': ['дорогами'],
#  'доргами': ['дорогами'],
#  'дороами': ['дорогами'],
#  'дорогми': ['дорогами', 'дорогими'],
#  'дорогаи': ['дорогами'],
#  'дорогам': ['дорогами'],
#  'азвание': ['название'],
#  'нзвание': ['название'],
#  'навание': ['название'],
#  'назание': ['название'],
#  'назвние': ['название'],
#  'назваие': ['название'],
#  'назване': ['название', 'названые', 'названое'],
#  'названи': ['название',
#   'названия',
#   'названию',
#   'названий',
#   'названии',
#   'названии'],
#  'вляется': ['является'],
#  'яляется': ['является'],
#  'явяется': ['является'],
#  'явлется': ['является'],
#  'являтся': ['является', 'являются', 'являться'],
#  'являеся': ['является', 'являемся'],
#  'являетя': ['является', 'являетcя'],
#  'являетс': ['является'],
#  'угубо': ['сугубо'],
#  'сгубо': ['сугубо'],
#  'суубо': ['сугубо'],
#  'сугбо': ['сугубо'],
#  'сугуо': ['сугубо'],
#  'сугуб': ['сугубо'],
#  'фициальным': ['официальным'],
#  'оициальным': ['официальным'],
#  'офциальным': ['официальным'],
#  'офииальным': ['официальным'],
#  'офицальным': ['официальным'],
#  'официльным': ['официальным'],
#  'официаьным': ['официальным'],
#  'официалным': ['официальным'],
#  'официальым': ['официальным'],
#  'официальнм': ['официальным', 'официальном'],
#  'официальны': ['официальным', 'официальный', 'официальных', 'официальные'],
#  'естное': ['местное', 'честное'],
#  'мстное': ['местное'],
#  'метное': ['местное'],
#  'месное': ['местное'],
#  'местое': ['местное'],
#  'местне': ['местное', 'местные'],
#  'местно': ['местное', 'местном', 'местной', 'уместно'],
#  'аселение': ['население', 'заселение'],
#  'нселение': ['население'],
#  'наеление': ['население'],
#  'насление': ['население'],
#  'насеение': ['население'],
#  'населние': ['население'],
#  'населеие': ['население'],
#  'населене': ['население'],
#  'населени': ['население', 'населения', 'населению', 'населении', 'населении'],
#  'спользует': ['использует'],
#  'ипользует': ['использует'],
#  'исользует': ['использует'],
#  'испльзует': ['использует'],
#  'испоьзует': ['использует'],
#  'исползует': ['использует'],
#  'испольует': ['использует'],
#  'использет': ['использует'],
#  'использут': ['использует', 'используют'],
#  'используе': ['использует', 'используем'],
#  'сключительно': ['исключительно'],
#  'иключительно': ['исключительно'],
#  'ислючительно': ['исключительно'],
#  'искючительно': ['исключительно'],
#  'исклчительно': ['исключительно'],
#  'исклюительно': ['исключительно'],
#  'исключтельно': ['исключительно'],
#  'исключиельно': ['исключительно'],
#  'исключитльно': ['исключительно'],
#  'исключитеьно': ['исключительно'],
#  'исключително': ['исключительно'],
#  'исключительо': ['исключительно'],
#  'исключительн': ['исключительно'],
#  'льтернативное': ['альтернативное'],
#  'аьтернативное': ['альтернативное'],
#  'алтернативное': ['альтернативное'],
#  'альернативное': ['альтернативное'],
#  'альтрнативное': ['альтернативное'],
#  'альтенативное': ['альтернативное'],
#  'альтеративное': ['альтернативное'],
#  'альтернтивное': ['альтернативное'],
#  'альтернаивное': ['альтернативное'],
#  'альтернатвное': ['альтернативное'],
#  'альтернатиное': ['альтернативное'],
#  'альтернативое': ['альтернативное'],
#  'альтернативне': ['альтернативное', 'альтернативные'],
#  'альтернативно': ['альтернативное', 'альтернативном', 'альтернативной'],
#  'итрый': ['хитрый'],
#  'хтрый': ['хитрый'],
#  'хирый': ['хитрый'],
#  'хитый': ['хитрый'],
#  'хитрй': ['хитрый', 'хитрой'],
#  'хитры': ['хитрый', 'хитрые', 'хитрым'],
#  'потребляется': ['употребляется'],
#  'уотребляется': ['употребляется'],
#  'уптребляется': ['употребляется'],
#  'упоребляется': ['употребляется'],
#  'употебляется': ['употребляется'],
#  'употрбляется': ['употребляется'],
#  'употреляется': ['употребляется'],
#  'употребяется': ['употребляется'],
#  'употреблется': ['употребляется'],
#  'употреблятся': ['употребляется', 'употребляются', 'употребляться'],
#  'употребляеся': ['употребляется'],
#  'употребляетя': ['употребляется'],
#  'употребляетс': ['употребляется'],
#  'зыковой': ['языковой'],
#  'яыковой': ['языковой'],
#  'язковой': ['языковой'],
#  'языовой': ['языковой'],
#  'языквой': ['языковой'],
#  'языкоой': ['языковой'],
#  'языковй': ['языковой', 'языковый'],
#  'языково': ['языковой', 'языковое', 'языковом'],
#  'борот': ['оборот'],
#  'оорот': ['оборот'],
#  'оброт': ['оборот'],
#  'обоот': ['оборот'],
#  'оборт': ['оборот'],
#  'оборо': ['оборот'],
#  'итром': ['хитром'],
#  'хтром': ['хитром'],
#  'хиром': ['хитром', 'хироми', 'хирому'],
#  'хитом': ['хитром', 'хитоми'],
#  'хитрм': ['хитром', 'хитрым'],
#  'хитро': ['хитром', 'хитрое', 'хитрой'],
#  'анее': ['ранее', 'анете'],
#  'рнее': ['ранее'],
#  'раее': ['ранее'],
#  'ране': ['ранее',
#   'ранее',
#   'ранен',
#   'иране',
#   'ранге',
#   'ранке',
#   'ранне',
#   'ранне',
#   'ранец',
#   'аране',
#   'эране',
#   'рагне',
#   'руане',
#   'райне',
#   'вране',
#   'гране',
#   'ранде'],
#  'спользуемые': ['используемые'],
#  'ипользуемые': ['используемые'],
#  'исользуемые': ['используемые'],
#  'испльзуемые': ['используемые'],
#  'испоьзуемые': ['используемые'],
#  'исползуемые': ['используемые'],
#  'испольуемые': ['используемые'],
#  'использемые': ['используемые'],
#  'использумые': ['используемые'],
#  'используеые': ['используемые'],
#  'используеме': ['используемые', 'используемое'],
#  'используемы': ['используемые',
#   'используемый',
#   'используемых',
#   'используемым'],
#  'азвания': ['названия'],
#  'нзвания': ['названия'],
#  'навания': ['названия'],
#  'назания': ['названия'],
#  'назвния': ['названия'],
#  'назваия': ['названия'],
#  'названя': ['названия', 'названія'],
#  'есчаный': ['песчаный'],
#  'псчаный': ['песчаный'],
#  'печаный': ['песчаный', 'печатный'],
#  'песаный': ['песчаный'],
#  'песчный': ['песчаный', 'песочный'],
#  'песчаый': ['песчаный'],
#  'песчанй': ['песчаный', 'песчаной'],
#  'песчаны': ['песчаный', 'песчаные', 'песчаных', 'песчаным'],
#  'звестковый': ['известковый'],
#  'ивестковый': ['известковый'],
#  'изестковый': ['известковый'],
#  'извстковый': ['известковый'],
#  'изветковый': ['известковый'],
#  'извесковый': ['известковый'],
#  'известовый': ['известковый'],
#  'известквый': ['известковый'],
#  'известкоый': ['известковый'],
#  'известковй': ['известковый'],
#  'известковы': ['известковый', 'известковых', 'известковым', 'известковые'],
#  'снован': ['основан'],
#  'онован': ['основан', 'донован'],
#  'осован': ['основан'],
#  'оснван': ['основан'],
#  'осноан': ['основан'],
#  'основн': ['основан', 'основны'],
#  'основа': ['основан', 'основал', 'основав', 'основам', 'основах'],
#  '920-х': ['1920-х'],
#  '120-х': ['1920-х',
#   '1820-х',
#   '1420-х',
#   '1520-х',
#   '1620-х',
#   '1720-х',
#   '1120-х',
#   '1120-х',
#   '1290-х',
#   '1320-х'],
#  '190-х': ['1920-х',
#   '1970-х',
#   '1990-х',
#   '1990-х',
#   '1930-х',
#   '1960-х',
#   '1980-х',
#   '1890-х',
#   '1950-х',
#   '1940-х',
#   '1910-х',
#   '1900-х',
#   '1900-х',
#   '1790-х',
#   '1590-х',
#   '1690-х',
#   '1290-х'],
#  '192-х': ['1920-х'],
#  '1920х': ['1920-х'],
#  '1920-': ['1920-х', '1920-е', '1920-м'],
#  'одах': ['годах', 'водах', 'родах', 'ходах', 'кодах', 'модах'],
#  'гдах': ['годах'],
#  'гоах': ['годах', 'горах'],
#  'годх': ['годах'],
#  'года': ['годах',
#   'годам',
#   'годав',
#   'годар',
#   'ягода',
#   'голда',
#   'гогда',
#   'горда',
#   'годуа'],
#  'ереселенцами': ['переселенцами'],
#  'преселенцами': ['переселенцами'],
#  'пееселенцами': ['переселенцами'],
#  'перселенцами': ['переселенцами'],
#  'перееленцами': ['переселенцами'],
#  'пересленцами': ['переселенцами'],
#  'пересеенцами': ['переселенцами'],
#  'переселнцами': ['переселенцами'],
#  'переселецами': ['переселенцами'],
#  'переселенами': ['переселенцами'],
#  'переселенцми': ['переселенцами'],
#  'переселенцаи': ['переселенцами'],
#  'переселенцам': ['переселенцами'],
#  'з': ['из',
#   'за',
#   'уз',
#   'кз',
#   'зе',
#   'зя',
#   'мз',
#   'оз',
#   'юз',
#   'зы',
#   'зи',
#   'сз',
#   'аз',
#   'зб',
#   'яз',
#   'зэ',
#   'зо',
#   'фз',
#   'гз'],
#  'и': ['из',
#   'их',
#   'ни',
#   'ли',
#   'им',
#   'си',
#   'аи',
#   'ди',
#   'ти',
#   'уи',
#   'иж',
#   'юи',
#   'ир',
#   'ин',
#   'ки',
#   'ри',
#   'чи',
#   'пи',
#   'ид',
#   'би',
#   'ги',
#   'иф',
#   'хи',
#   'ши',
#   'ик',
#   'ил',
#   'ив',
#   'ци',
#   'ми',
#   'ви',
#   'ис',
#   'зи',
#   'ия',
#   'щи',
#   'ио',
#   'иг',
#   'иц',
#   'еи',
#   'ип',
#   'иб',
#   'иа',
#   'иу',
#   'ий',
#   'ит',
#   'ии',
#   'ии',
#   'ие',
#   'фи',
#   '5и',
#   'kи',
#   'ои'],
#  'оседних': ['соседних'],
#  'сседних': ['соседних'],
#  'соедних': ['соседних'],
#  'сосдних': ['соседних'],
#  'сосених': ['соседних'],
#  'соседих': ['соседних'],
#  'соседнх': ['соседних'],
#  'соседни': ['соседних', 'соседние', 'соседним', 'соседний'],
#  'ёл': ['сёл', 'шёл', 'вёл', 'ёлу'],
#  'сл': ['сёл',
#   'сил',
#   'сал',
#   'сел',
#   'сул',
#   'исл',
#   'сэл',
#   'сол',
#   'сло',
#   'рсл',
#   'асл',
#   'нсл',
#   '7сл',
#   'тсл'],
#  'сё': ['сёл', 'всё', 'сён', 'сёр', 'сём'],
#  'ламасово': ['аламасово'],
#  'аамасово': ['аламасово'],
#  'алмасово': ['аламасово'],
#  'алаасово': ['аламасово'],
#  'аламсово': ['аламасово'],
#  'аламаово': ['аламасово'],
#  'аламасво': ['аламасово'],
#  'аламасоо': ['аламасово'],
#  'аламасов': ['аламасово'],
#  'арышкино': ['нарышкино'],
#  'нрышкино': ['нарышкино'],
#  'наышкино': ['нарышкино'],
#  'наршкино': ['нарышкино'],
#  'нарыкино': ['нарышкино'],
#  'нарышино': ['нарышкино'],
#  'нарышкно': ['нарышкино'],
#  'нарышкио': ['нарышкино'],
#  'нарышкин': ['нарышкино', 'нарышкина', 'нарышкину'],
#  'асположенных': ['расположенных'],
#  'рсположенных': ['расположенных'],
#  'раположенных': ['расположенных'],
#  'расоложенных': ['расположенных'],
#  'распложенных': ['расположенных'],
#  'распооженных': ['расположенных'],
#  'располженных': ['расположенных'],
#  'располоенных': ['расположенных'],
#  'расположнных': ['расположенных'],
#  'расположеных': ['расположенных', 'расположенных'],
#  'расположеннх': ['расположенных'],
#  'расположенны': ['расположенных',
#   'расположенные',
#   'расположенный',
#   'расположенным'],
#  'оответственно': ['соответственно'],
#  'сответственно': ['соответственно', 'соответственно'],
#  'сооветственно': ['соответственно'],
#  'соотетственно': ['соответственно'],
#  'соотвтственно': ['соответственно'],
#  'соотвественно': ['соответственно'],
#  'соответтвенно': ['соответственно'],
#  'соответсвенно': ['соответственно'],
#  'соответстенно': ['соответственно'],
#  'соответствнно': ['соответственно'],
#  'соответствено': ['соответственно', 'соответственно'],
#  'соответственн': ['соответственно'],
#  'ознесенском': ['вознесенском'],
#  'взнесенском': ['вознесенском'],
#  'вонесенском': ['вознесенском'],
#  'возесенском': ['вознесенском'],
#  'вознсенском': ['вознесенском'],
#  'вознеенском': ['вознесенском'],
#  'вознеснском': ['вознесенском'],
#  'вознесеском': ['вознесенском'],
#  'вознесенком': ['вознесенском'],
#  'вознесенсом': ['вознесенском'],
#  'вознесенскм': ['вознесенском', 'вознесенским'],
#  'вознесенско': ['вознесенском', 'вознесенское', 'вознесенской'],
#  'радиционно': ['традиционно', 'радиационно'],
#  'тадиционно': ['традиционно'],
#  'трдиционно': ['традиционно'],
#  'траиционно': ['традиционно'],
#  'традционно': ['традиционно'],
#  'традиионно': ['традиционно'],
#  'традицонно': ['традиционно', 'традиціонно'],
#  'традицинно': ['традиционно'],
#  'традиционо': ['традиционно', 'традиционно'],
#  'традиционн': ['традиционно', 'традиционен', 'традиционна', 'традиционны'],
#  'осёлке': ['посёлке'],
#  'псёлке': ['посёлке'],
#  'поёлке': ['посёлке'],
#  'послке': ['посёлке', 'поселке', 'посылке'],
#  'посёке': ['посёлке'],
#  'посёле': ['посёлке'],
#  'или': ['жили',
#   'чили',
#   'ильи',
#   'кили',
#   'били',
#   'лили',
#   'шили',
#   'илия',
#   'имли',
#   'мили',
#   'илии',
#   'илии',
#   'илим',
#   'илиа',
#   'илию',
#   'сили',
#   'илие',
#   'фили',
#   'хили',
#   'эили',
#   'пили',
#   'илжи',
#   'дили',
#   'ирли',
#   'цили',
#   'нили',
#   'илит'],
#  'жли': ['жили', 'жюли'],
#  'жии': ['жили', 'живи', 'жийи', 'жижи', 'жити'],
#  'жил': ['жили',
#   'жила',
#   'ожил',
#   'жилы',
#   'жиль',
#   'жиля',
#   'джил',
#   'жило',
#   'жиле',
#   'жилю'],
#  'абочие': ['рабочие'],
#  'рбочие': ['рабочие'],
#  'раочие': ['рабочие'],
#  'рабчие': ['рабочие'],
#  'рабоие': ['рабочие'],
#  'рабоче': ['рабочие', 'рабочее', 'рабочее', 'рабочей', 'рабочем'],
#  'рабочи': ['рабочие', 'рабочий', 'рабочих', 'рабочим'],
#  'овхоза': ['совхоза'],
#  'свхоза': ['совхоза'],
#  'сохоза': ['совхоза'],
#  'совоза': ['совхоза'],
#  'совхза': ['совхоза'],
#  'совхоа': ['совхоза'],
#  'совхоз': ['совхоза', 'совхозе', 'совхозы', 'совхозу'],
#  'перёд': ['вперёд'],
#  'верёд': ['вперёд'],
#  'впрёд': ['вперёд'],
#  'впеёд': ['вперёд'],
#  'вперд': ['вперёд', 'вперед'],
#  'вперё': ['вперёд'],
#  'ентр': ['центр'],
#  'цнтр': ['центр'],
#  'цетр': ['центр'],
#  'ценр': ['центр'],
#  'цент': ['центр', 'ценит', 'ценят', 'цента'],
#  'озле': ['возле', 'козле'],
#  'взле': ['возле', 'взлет', 'везле'],
#  'воле': ['возле',
#   'волне',
#   'волге',
#   'волен',
#   'волей',
#   'волею',
#   'волке',
#   'волер'],
#  'возе': ['возле', 'ввозе', 'ввозе'],
#  'возл': ['возле', 'возил'],
#  'осёлка': ['посёлка'],
#  'псёлка': ['посёлка'],
#  'поёлка': ['посёлка'],
#  'послка': ['посёлка', 'поселка', 'посылка'],
#  'посёка': ['посёлка'],
#  'посёла': ['посёлка'],
#  'арьер': ['карьер', 'барьер'],
#  'крьер': ['карьер', 'курьер'],
#  'каьер': ['карьер'],
#  'карер': ['карьер', 'картер', 'карвер', 'карцер'],
#  'карьр': ['карьер'],
#  'карье': ['карьер', 'картье', 'карлье'],
#  'де': ['где',
#   'две',
#   'дел',
#   'дер',
#   'дед',
#   'дей',
#   'дем',
#   'аде',
#   'деп',
#   'дес',
#   'дне',
#   'ден',
#   'дае',
#   'дея',
#   'дев',
#   'еде',
#   'оде',
#   'деи',
#   'дет',
#   'дме',
#   'деф',
#   'дез',
#   'деа',
#   'дею',
#   'эде',
#   'дех',
#   'дек',
#   'иде',
#   'деч'],
#  'ге': ['где',
#   'юге',
#   'гей',
#   'ген',
#   'гея',
#   'гае',
#   'гел',
#   'геи',
#   'пге',
#   'гею',
#   'эге',
#   'гек',
#   'гер',
#   'гед'],
#  'гд': ['где',
#   'год',
#   'гуд',
#   'гдр',
#   'мгд',
#   'гдф',
#   'гды',
#   'агд',
#   'гад',
#   'гжд',
#   'игд',
#   'гид',
#   'гед',
#   'гпд'],
#  'ктивно': ['активно'],
#  'ативно': ['активно'],
#  'акивно': ['активно'],
#  'актвно': ['активно'],
#  'актино': ['активно', 'актинов', 'актином'],
#  'активо': ['активно', 'активов', 'активом'],
#  'активн': ['активно', 'активны', 'активна', 'активен'],
#  'обывали': ['добывали', 'побывали', 'обмывали', 'отбывали'],
#  'дбывали': ['добывали'],
#  'доывали': ['добывали'],
#  'добвали': ['добывали'],
#  'добыали': ['добывали'],
#  'добывли': ['добывали'],
#  'добываи': ['добывали'],
#  'добывал': ['добывали', 'добывала'],
#  'оломитовую': ['доломитовую'],
#  'дломитовую': ['доломитовую'],
#  'доомитовую': ['доломитовую'],
#  'долмитовую': ['доломитовую'],
#  'долоитовую': ['доломитовую'],
#  'доломтовую': ['доломитовую'],
#  'доломиовую': ['доломитовую'],
#  'доломитвую': ['доломитовую'],
#  'доломитоую': ['доломитовую'],
#  'доломитовю': ['доломитовую'],
#  'доломитову': ['доломитовую'],
#  'уку': ['муку',
#   'руку',
#   'луку',
#   'укус',
#   'утку',
#   'дуку',
#   'укуз',
#   'фуку',
#   'щуку'],
#  'мку': ['муку', 'мику', 'маку', 'ямку', 'амку'],
#  'муу': ['муку',
#   'мужу',
#   'муру',
#   'муху',
#   'музу',
#   'муту',
#   'муму',
#   'муну',
#   'мусу'],
#  'мук': ['муку', 'муки', 'моук', 'мука', 'мбук', 'мунк', 'муке'],
#  'утовый': ['бутовый'],
#  'бтовый': ['бутовый'],
#  'буовый': ['бутовый'],
#  'бутвый': ['бутовый'],
#  'бутоый': ['бутовый'],
#  'бутовй': ['бутовый'],
#  'бутовы': ['бутовый'],
#  'амень': ['камень'],
#  'кмень': ['камень'],
#  'каень': ['камень'],
#  'камнь': ['камень'],
#  'камеь': ['камень', 'камедь'],
#  'камен': ['камень', 'кармен', 'каменя', 'камене', 'камден', 'камфен'],
#  'астоящее': ['настоящее'],
#  'нстоящее': ['настоящее'],
#  'натоящее': ['настоящее'],
#  'насоящее': ['настоящее'],
#  'настящее': ['настоящее'],
#  'настощее': ['настоящее'],
#  'настояее': ['настоящее'],
#  'настояще': ['настоящее', 'настоящее', 'настоящие', 'настоящей', 'настоящем'],
#  'ремя': ['время', 'тремя', 'бремя', 'ремня'],
#  'вемя': ['время'],
#  'врмя': ['время', 'врёмя'],
#  'врея': ['время', 'еврея', 'иврея'],
#  'врем': ['время'],
#  'фициально': ['официально'],
#  'оициально': ['официально'],
#  'офциально': ['официально'],
#  'офииально': ['официально'],
#  'офицально': ['официально'],
#  'официльно': ['официально'],
#  'официаьно': ['официально'],
#  'официално': ['официально'],
#  'официальо': ['официально'],
#  'официальн': ['официально', 'официальна'],
#  'акрыт': ['закрыт', 'накрыт'],
#  'зкрыт': ['закрыт'],
#  'зарыт': ['закрыт', 'зарыты'],
#  'закыт': ['закрыт'],
#  'закрт': ['закрыт'],
#  'закры': ['закрыт', 'закрыл', 'закрыв'],
#  'п': ['по',
#   'кп',
#   'пл',
#   'пр',
#   'пе',
#   'пи',
#   'пп',
#   'пп',
#   'пд',
#   'оп',
#   'пт',
#   'пн',
#   'пс',
#   'мп',
#   'нп',
#   'фп',
#   'пэ',
#   'пк',
#   'сп',
#   'пв',
#   'гп',
#   'пж',
#   'еп',
#   'цп',
#   'па',
#   'ап',
#   'пу',
#   'чп',
#   'тп',
#   'вп',
#   'дп',
#   'п2',
#   'пг',
#   'ип',
#   'яп',
#   'пь',
#   'юп',
#   'пб',
#   'рп',
#   'уп',
#   'пo',
#   '5п',
#   'пм',
#   'бп',
#   'пч'],
#  'анным': ['данным', 'санным'],
#  'днным': ['данным', 'донным'],
#  'даным': ['данным', 'данным', 'дачным', 'давным'],
#  'даннм': ['данным', 'данном'],
#  'данны': ['данным', 'данных', 'данные', 'данный'],
#  'ода': ['года',
#   'одна',
#   'вода',
#   'рода',
#   'орда',
#   'кода',
#   'мода',
#   'хода',
#   'йода',
#   'дода',
#   'тода',
#   'олда',
#   'одда',
#   'одда',
#   'сода',
#   'лода',
#   'одва',
#   'нода',
#   'одах',
#   'одра',
#   'одиа',
#   'пода'],
#  'гда': ['года', 'гуда', 'егда', 'гида', 'гвда', 'геда', 'гада'],
#  'гоа': ['года',
#   'гора',
#   'гола',
#   'гофа',
#   'гога',
#   'гоба',
#   'гоша',
#   'гона',
#   'гойа',
#   'гота',
#   'гоха',
#   'гоза',
#   'гопа',
#   'гоар'],
#  'год': ['года',
#   'году',
#   'годы',
#   'ягод',
#   'горд',
#   'годе',
#   'голд',
#   'годй',
#   'годи',
#   'годо',
#   'говд',
#   'гонд',
#   'годъ',
#   'годж',
#   'годв',
#   'годa'],
#  'арактеризовался': ['характеризовался'],
#  'храктеризовался': ['характеризовался'],
#  'хаактеризовался': ['характеризовался'],
#  'харктеризовался': ['характеризовался'],
#  'харатеризовался': ['характеризовался'],
#  'харакеризовался': ['характеризовался'],
#  'характризовался': ['характеризовался'],
#  'характеизовался': ['характеризовался'],
#  'характерзовался': ['характеризовался'],
#  'характериовался': ['характеризовался'],
#  'характеризвался': ['характеризовался'],
#  'характеризоался': ['характеризовался'],
#  'характеризовлся': ['характеризовался'],
#  'характеризовася': ['характеризовался'],
#  'характеризоваля': ['характеризовался'],
#  'характеризовалс': ['характеризовался'],
#  'ак': ['как',
#   'так',
#   'афк',
#   'жак',
#   'рак',
#   'мак',
#   'анк',
#   'акт',
#   'чак',
#   'яак',
#   'аки',
#   'бак',
#   'оак',
#   'акр',
#   'лак',
#   'арк',
#   'аик',
#   'вак',
#   'аек',
#   'пак',
#   'апк',
#   'акб',
#   'зак',
#   'айк',
#   'акн',
#   'ака',
#   'хак',
#   'нак',
#   'акв',
#   'сак',
#   'аск',
#   'ахк',
#   'акъ',
#   'гак',
#   'авк',
#   'ако',
#   'акс',
#   'аок',
#   'акд',
#   'дак'],
#  'кк': ['как',
#   'ркк',
#   'кпк',
#   'крк',
#   'цкк',
#   'кук',
#   'экк',
#   'кмк',
#   'ктк',
#   'кфк',
#   'кск',
#   'мкк',
#   'скк',
#   'ккс',
#   'ккд',
#   'дкк',
#   'кка',
#   'кек',
#   'кик'],
#  'ка': ['как',
#   'ска',
#   'кай',
#   'кая',
#   'кам',
#   'каш',
#   'ока',
#   'дка',
#   'каэ',
#   'ука',
#   'кан',
#   'кал',
#   'кда',
#   'каф',
#   'кат',
#   'тка',
#   'ака',
#   'кпа',
#   'кац',
#   'каз',
#   'кса',
#   'куа',
#   'киа',
#   'каи',
#   'кап',
#   'кма',
#   'кха',
#   'рка',
#   'мка',
#   'ека',
#   'кна',
#   '9ка',
#   'ка3',
#   'кае',
#   'юка',
#   'бка',
#   'ика',
#   'кар',
#   'яка',
#   'кка',
#   'кка',
#   'кас',
#   'кша',
#   'кав',
#   'кау',
#   'као'],
#  'еперспективный': ['неперспективный'],
#  'нперспективный': ['неперспективный'],
#  'неерспективный': ['неперспективный'],
#  'непрспективный': ['неперспективный'],
#  'непеспективный': ['неперспективный'],
#  'неперпективный': ['неперспективный'],
#  'неперсективный': ['неперспективный'],
#  'неперспктивный': ['неперспективный'],
#  'неперспетивный': ['неперспективный'],
#  'неперспекивный': ['неперспективный'],
#  'неперспектвный': ['неперспективный'],
#  'неперспектиный': ['неперспективный'],
#  'неперспективый': ['неперспективный'],
#  'неперспективнй': ['неперспективный'],
#  'неперспективны': ['неперспективный', 'неперспективным', 'неперспективные'],
#  'десь': ['здесь', 'днесь', 'десть'],
#  'зесь': ['здесь'],
#  'здсь': ['здесь', 'здѣсь'],
#  'здеь': ['здесь'],
#  'здес': ['здесь'],
#  'асчитывалось': ['насчитывалось'],
#  'нсчитывалось': ['насчитывалось'],
#  'начитывалось': ['насчитывалось'],
#  'наситывалось': ['насчитывалось'],
#  'насчтывалось': ['насчитывалось'],
#  'насчиывалось': ['насчитывалось'],
#  'насчитвалось': ['насчитывалось'],
#  'насчитыалось': ['насчитывалось'],
#  'насчитывлось': ['насчитывалось'],
#  'насчитываось': ['насчитывалось'],
#  'насчитывалсь': ['насчитывалось', 'насчитывались'],
#  'насчитывалоь': ['насчитывалось'],
#  'насчитывалос': ['насчитывалось'],
#  'озяйства': ['хозяйства'],
#  'хзяйства': ['хозяйства'],
#  'хояйства': ['хозяйства'],
#  'хозйства': ['хозяйства'],
#  'хозяства': ['хозяйства'],
#  'хозяйтва': ['хозяйства'],
#  'хозяйсва': ['хозяйства'],
#  'хозяйста': ['хозяйства'],
#  'хозяйств': ['хозяйства', 'хозяйство', 'хозяйству', 'хозяйстве'],
#  'ителя': ['жителя'],
#  'жтеля': ['жителя'],
#  'жиеля': ['жителя'],
#  'житля': ['жителя'],
#  'житея': ['жителя'],
#  'жител': ['жителя', 'жители', 'житель', 'жителю'],
#  'одоснабжение': ['водоснабжение'],
#  'вдоснабжение': ['водоснабжение'],
#  'вооснабжение': ['водоснабжение'],
#  'водснабжение': ['водоснабжение'],
#  'водонабжение': ['водоснабжение'],
#  'водосабжение': ['водоснабжение'],
#  'водоснбжение': ['водоснабжение'],
#  'водоснажение': ['водоснабжение'],
#  'водоснабение': ['водоснабжение'],
#  'водоснабжние': ['водоснабжение'],
#  'водоснабжеие': ['водоснабжение'],
#  'водоснабжене': ['водоснабжение'],
#  'водоснабжени': ['водоснабжение', 'водоснабжения', 'водоснабжению'],
#  'существлялось': ['осуществлялось'],
#  'оуществлялось': ['осуществлялось'],
#  'осществлялось': ['осуществлялось'],
#  'осуествлялось': ['осуществлялось'],
#  'осущствлялось': ['осуществлялось'],
#  'осущетвлялось': ['осуществлялось'],
#  'осущесвлялось': ['осуществлялось'],
#  'осущестлялось': ['осуществлялось'],
#  'осуществялось': ['осуществлялось'],
#  'осуществллось': ['осуществлялось'],
#  'осуществляось': ['осуществлялось'],
#  'осуществлялсь': ['осуществлялось', 'осуществлялась', 'осуществлялись'],
#  'осуществлялоь': ['осуществлялось'],
#  'осуществлялос': ['осуществлялось'],
#  'олодцев': ['колодцев'],
#  'клодцев': ['колодцев'],
#  'коодцев': ['колодцев'],
#  'колдцев': ['колодцев'],
#  'колоцев': ['колодцев'],
#  'колодев': ['колодцев'],
#  'колодцв': ['колодцев'],
#  'колодце': ['колодцев', 'колодцем'],
#  'одников': ['родников'],
#  'рдников': ['родников', 'рудников'],
#  'роников': ['родников'],
#  'родиков': ['родников'],
#  'роднков': ['родников'],
#  'родниов': ['родников'],
#  'родникв': ['родников'],
#  'роднико': ['родников'],
#  'чреждения': ['учреждения'],
#  'уреждения': ['учреждения', 'упреждения'],
#  'учеждения': ['учреждения'],
#  'учрждения': ['учреждения'],
#  'учредения': ['учреждения'],
#  'учрежения': ['учреждения'],
#  'учреждния': ['учреждения'],
#  'учреждеия': ['учреждения'],
#  'учрежденя': ['учреждения'],
#  'учреждени': ['учреждения',
#   'учреждение',
#   'учреждению',
#   'учреждений',
#   'учреждении',
#   'учреждении'],
#  'оцкультбыта': ['соцкультбыта'],
#  'сцкультбыта': ['соцкультбыта'],
#  'сокультбыта': ['соцкультбыта'],
#  'соцультбыта': ['соцкультбыта'],
#  'соцкльтбыта': ['соцкультбыта'],
#  'соцкуьтбыта': ['соцкультбыта'],
#  'соцкултбыта': ['соцкультбыта'],
#  'соцкульбыта': ['соцкультбыта'],
#  'соцкультыта': ['соцкультбыта'],
#  'соцкультбта': ['соцкультбыта'],
#  'соцкультбыа': ['соцкультбыта'],
#  'соцкультбыт': ['соцкультбыта'],
#  'тсутствовали': ['отсутствовали'],
#  'осутствовали': ['отсутствовали'],
#  'отутствовали': ['отсутствовали'],
#  'отстствовали': ['отсутствовали'],
#  'отсуствовали': ['отсутствовали'],
#  'отсуттвовали': ['отсутствовали'],
#  'отсутсвовали': ['отсутствовали'],
#  'отсутстовали': ['отсутствовали'],
#  'отсутстввали': ['отсутствовали'],
#  'отсутствоали': ['отсутствовали'],
#  'отсутствовли': ['отсутствовали'],
#  'отсутствоваи': ['отсутствовали'],
#  'отсутствовал': ['отсутствовали', 'отсутствовала', 'отсутствовало'],
#  'оду': ['году',
#   'воду',
#   'одну',
#   'роду',
#   'ходу',
#   'коду',
#   'моду',
#   'одзу',
#   'одру',
#   'орду',
#   'одду',
#   'одду'],
#  'гду': ['году', 'нгду', 'геду', 'гдуд'],
#  'гоу': ['году', 'гору', 'голу', 'гону', 'гбоу', 'фгоу', 'мгоу'],
#  'озяйств': ['хозяйств'],
#  'хзяйств': ['хозяйств'],
#  'хояйств': ['хозяйств'],
#  'хозйств': ['хозяйств'],
#  'хозяств': ['хозяйств'],
#  'хозяйтв': ['хозяйств'],
#  'хозяйсв': ['хозяйств'],
#  'хозяйст': ['хозяйств'],
#  'ителей': ['жителей'],
#  'жтелей': ['жителей'],
#  'жиелей': ['жителей'],
#  'житлей': ['жителей'],
#  'житеей': ['жителей'],
#  'жителй': ['жителей'],
#  'жителе': ['жителей', 'жителем'],
#  'оторых': ['которых'],
#  'кторых': ['которых'],
#  'коорых': ['которых'],
#  'котрых': ['которых'],
#  'котоых': ['которых'],
#  'которх': ['которых'],
#  'которы': ['которых', 'которые', 'которым', 'который', 'конторы'],
#  'рудоспособного': ['трудоспособного'],
#  'тудоспособного': ['трудоспособного'],
#  'трдоспособного': ['трудоспособного'],
#  'труоспособного': ['трудоспособного'],
#  'трудспособного': ['трудоспособного'],
#  'трудопособного': ['трудоспособного'],
#  'трудосособного': ['трудоспособного'],
#  'трудоспсобного': ['трудоспособного'],
#  'трудоспообного': ['трудоспособного'],
#  'трудоспосбного': ['трудоспособного'],
#  'трудоспосоного': ['трудоспособного'],
#  'трудоспособого': ['трудоспособного'],
#  'трудоспособнго': ['трудоспособного'],
#  'трудоспособноо': ['трудоспособного'],
#  'трудоспособног': ['трудоспособного'],
#  'озраста': ['возраста'],
#  'взраста': ['возраста'],
#  'вораста': ['возраста'],
#  'возаста': ['возраста'],
#  'возрста': ['возраста'],
#  'возрата': ['возраста', 'возврата'],
#  'возраса': ['возраста'],
#  'возраст': ['возраста', 'возрасте', 'возрасту', 'возрасти'],
#  'нваря': ['января'],
#  'яваря': ['января'],
#  'янаря': ['января', 'янтаря'],
#  'янвря': ['января'],
#  'янвая': ['января'],
#  'январ': ['января', 'январь', 'январе', 'январю'],
#  'мелось': ['имелось'],
#  'иелось': ['имелось'],
#  'имлось': ['имелось'],
#  'имеось': ['имелось'],
#  'имелсь': ['имелось', 'имелись', 'имелась'],
#  'имелоь': ['имелось'],
#  'имелос': ['имелось'],
#  'е': ['не',
#   'же',
#   'её',
#   'ей',
#   'те',
#   'де',
#   'фе',
#   'ед',
#   'ею',
#   'ре',
#   'ее',
#   'ее',
#   'пе',
#   'ле',
#   'ен',
#   'dе',
#   'е4',
#   'зе',
#   'ес',
#   'е6',
#   'ге',
#   'е3',
#   'е5',
#   'е7',
#   'е1',
#   'е2',
#   'се',
#   'ея',
#   'ер',
#   'бе',
#   'ке',
#   'че',
#   'ме',
#   'еп',
#   'е8',
#   'ве',
#   'ек',
#   'еф',
#   'це',
#   'еи',
#   'ео',
#   '9е',
#   'żе',
#   'еш',
#   'ие',
#   'fе',
#   'ые',
#   'ел',
#   'еa',
#   '8е',
#   'еж',
#   'еҥ',
#   'ем'],
#  'олько': ['только'],
#  'тлько': ['только', 'тилько'],
#  'тоько': ['только'],
#  'толко': ['только', 'толком', 'толков'],
#  'тольо': ['только'],
#  'тольк': ['только'],
#  'стаётся': ['остаётся'],
#  'отаётся': ['остаётся', 'отдаётся'],
#  'осаётся': ['остаётся'],
#  'остётся': ['остаётся'],
#  'остатся': ['остаётся', 'остаться', 'остается', 'остаются'],
#  'остаёся': ['остаётся'],
#  'остаётя': ['остаётся'],
#  'остаётс': ['остаётся'],
#  'илым': ['жилым', 'милым'],
#  'жлым': ['жилым'],
#  'жиым': ['жилым', 'живым'],
#  'жилм': ['жилым', 'жилом', 'жилем'],
#  'жилы': ['жилым', 'жилых', 'жилые'],
#  'олучил': ['получил', 'отлучил'],
#  'плучил': ['получил'],
#  'поучил': ['получил', 'поручил'],
#  'полчил': ['получил'],
#  'полуил': ['получил'],
#  'получл': ['получил', 'получал', 'получчл', 'получчл'],
#  'получи': ['получил', 'получит', 'получив', 'получим'],
#  'азвитие': ['развитие'],
#  'рзвитие': ['развитие'],
#  'равитие': ['развитие'],
#  'разитие': ['развитие'],
#  'развтие': ['развитие'],
#  'развиие': ['развитие'],
#  'развите': ['развитие', 'развитые', 'развитое'],
#  'развити': ['развитие', 'развития', 'развитию', 'развитии', 'развитии'],
#  'лагодаря': ['благодаря'],
#  'багодаря': ['благодаря'],
#  'блгодаря': ['благодаря'],
#  'блаодаря': ['благодаря'],
#  'благдаря': ['благодаря'],
#  'благоаря': ['благодаря'],
#  'благодря': ['благодаря'],
#  'благодая': ['благодаря'],
#  'благодар': ['благодаря', 'благодарю'],
#  'воей': ['своей', 'хвоей', 'твоей', 'волей'],
#  'соей': ['своей', 'солей', 'собей', 'соней'],
#  'свей': ['своей', 'свейн', 'свейо', 'свейу'],
#  'свой': ['своей', 'савой', 'совой'],
#  'свое': ['своей', 'своем', 'своде', 'своею'],
#  'лизости': ['близости'],
#  'бизости': ['близости'],
#  'блзости': ['близости'],
#  'блиости': ['близости'],
#  'близсти': ['близости'],
#  'близоти': ['близости'],
#  'близоси': ['близости'],
#  'близост': ['близости', 'близость'],
#  'вятым': ['святым', 'взятым'],
#  'сятым': ['святым', 'снятым'],
#  'свтым': ['святым'],
#  'свяым': ['святым'],
#  'святм': ['святым', 'святом'],
#  'святы': ['святым', 'святых', 'святые', 'святый'],
#  'сточникам': ['источникам'],
#  'иточникам': ['источникам'],
#  'исочникам': ['источникам'],
#  'истчникам': ['источникам'],
#  'истоникам': ['источникам'],
#  'источикам': ['источникам'],
#  'источнкам': ['источникам'],
#  'источниам': ['источникам'],
#  'источникм': ['источникам', 'источником'],
#  'источника': ['источникам', 'источниках'],
#  'олукилометре': ['полукилометре'],
#  'плукилометре': ['полукилометре'],
#  'поукилометре': ['полукилометре'],
#  'полкилометре': ['полукилометре'],
#  'полуилометре': ['полукилометре'],
#  'полуклометре': ['полукилометре'],
#  'полукиометре': ['полукилометре'],
#  'полукилметре': ['полукилометре'],
#  'полукилоетре': ['полукилометре'],
#  'полукиломтре': ['полукилометре'],
#  'полукиломере': ['полукилометре'],
#  'полукиломете': ['полукилометре'],
#  'полукилометр': ['полукилометре', 'полукилометра'],
#  'азанский': ['казанский'],
#  'кзанский': ['казанский'],
#  ...}

# %% [markdown]
# Пишем функцию по исправлению опечаток
#
# * генерируем удаления,
#
# * добавляем в список кандидатов а) варианты исправления текущего удаления, б) само удаление, если оно есть в изначальном словаре,
#
# * возвращаем
#         - самого вероятного кандидата на исправление, если удалось найти хоть какие-то варианты исправления,
#         - изначальное слово во всех других случаях

# %%
def P(word, N=N):
    return vocab[word] / N

def correction(vocab, word: 'str') -> str:
    w_deletes = generate_deletes(word)
    d_candidates = []
    for w in w_deletes:
        if w in deletes_vocab:
            d_candidates.extend(deletes_vocab.get(w))
        elif w in vocab:
            d_candidates.append(w)
    if d_candidates:
        return max(d_candidates, key=P)
    return word

# %%
# %%time
correction(vocab, 'прогрраммирование')
# Out:
# Wall time: 0 ns
# 'программированием'

# %%
# %%time
correction(vocab, 'лекция')
# Out:
# Wall time: 0 ns
# 'лекции'

# %%
from tqdm.notebook import tqdm

# %% [markdown]
# Попробуем процентно оценить качество работы функции на данных

# %%
bad = open('data/sents_with_mistakes.txt', encoding='utf8').read().splitlines()
true = open('data/correct_sents.txt', encoding='utf8').read().splitlines()

# %%
from string import punctuation

def align_words(sent_1, sent_2):
    tokens_1 = sent_1.lower().split()
    tokens_2 = sent_2.lower().split()
    
    tokens_1 = [token.strip(punctuation) for token in tokens_1]
    tokens_2 = [token.strip(punctuation) for token in tokens_2]
    
    tokens_1 = [token for token in tokens_1 if token]
    tokens_2 = [token for token in tokens_2 if token]
    
    assert len(tokens_1) == len(tokens_2)
    
    return list(zip(tokens_1, tokens_2))

# %%
correct = 0
total = 0

total_mistaken = 0
mistaken_fixed = 0

total_correct = 0
correct_broken = 0

cashed = {}
for i in tqdm(range(len(true))):
    word_pairs = align_words(true[i], bad[i])
    for pair in word_pairs:
        # чтобы два раза не исправлять одно и тоже слово - закешируем его
        # перед тем как считать исправление проверим нет ли его в кеше
        
        predicted = cashed.get(pair[1], correction(vocab, pair[1]))
        cashed[pair[1]] = predicted
        
        if predicted == pair[0]:
            correct += 1
        total += 1
        
        if pair[0] == pair[1]:
            total_correct += 1
            if pair[0] !=  predicted:
                correct_broken += 1
        else:
            total_mistaken += 1
            if pair[0] == predicted:
                mistaken_fixed += 1
# Out:
#   0%|          | 0/915 [00:00<?, ?it/s]

# %%
print(correct/total)
print(mistaken_fixed/total_mistaken)
print(correct_broken/total_correct)
# Out:
# 0.5198599299649825
# 0.2857142857142857
# 0.44550361777879866

# %% [markdown]
# Только 28% опечаток исправляются корректно.
#
# Посмотрим, как исправляются самые частотные опечатки

# %%
mistakes = []
total = 0
for i in range(len(true)):
    word_pairs = align_words(true[i], bad[i])
    
    for pair in word_pairs:
        if pair[0] != pair[1]:
            mistakes.append(pair)
        total += 1

# %%
[(wt[0], wt[1], correction(vocab, wt[1])) for wt, _ in Counter(mistakes).most_common(10)]
# Out:
# [('сегодня', 'седня', 'седан'),
#  ('вообще', 'вобще', 'общей'),
#  ('вообще', 'ваще', 'чаще'),
#  ('естественно', 'естесственно', 'естественной'),
#  ('хочется', 'хочеться', 'хочется'),
#  ('кстати', 'кстате', 'статей'),
#  ('очень', 'ооочень', ''),
#  ('как-то', 'както', 'какой'),
#  ('очень', 'оооочень', ''),
#  ('это', 'ето', 'что')]

# %% [markdown]
# ## *3. Чтение. (2 балла)

# %% [markdown]
# Прочитайте эту главу в книге Speech and Language Processing - https://web.stanford.edu/~jurafsky/slp3/2.pdf .
# Ответьте на следующий вопрос:
#
# 1. Что такое Byte-Pair Encoding (опишите по-русски, как минимум 10 предложениями)?
#
# *Это задание не связано напрямую с исправлением опечаток, но это важная тема, к которой мы вернемся в конце курса

# %% [markdown]
# 1. Один из методов токенизации, который выучивает некоторые подпоследовательности из строк, а затем применяет их при сегментации сырого текста. Т. е. по идее он должен находить в тексте некоторые морфемы вроде частотных суффиксов и приставок.
# 2. Самый простой из алгоритмов токенизации такого рода. SentencePiece частично включает в себя именно этот алгоритм.
# 3. Работает следующим образом: делит простейшие токены (разделенные пробелом) в корпусе посимвольно, находит самые частотные пары символов и объединяет их в одну последовательность. Эту последовательность добавляет в словарь символов. И так далее до некоторого критерия остановки.
#
# Из интереса решила попробовать написать немного кода на это, чтобы лучше понять. Оставлю ниже

# %%
bpe_corpus = '''Once we’ve learned our vocabulary, the token parser is used to tokenize a test
sentence. The token parser just runs on the test data the merges we have learned
from the training data, greedily, in the order we learned them. (Thus the frequencies
in the test data don’t play a role, just the frequencies in the training data). So first
we segment each test sentence word into characters. Then we apply the first rule:
replace every instance of er in the test corpus with er, and then the second rule:
replace every instance of er in the test corpus with er , and so on. By the end,
if the test corpus contained the word newer, it would be tokenized as a full
word. But a new (unknown) word like lower would be merged into the two
tokens low er.'''

# %%
bpe_corpus_l = [token.strip(punctuation) for token in bpe_corpus.lower().split()]

# %%
corpus_vocab = Counter(bpe_corpus_l)

# %%
corpus_vocab
# Out:
# Counter({'once': 1,
#          'we’ve': 1,
#          'learned': 3,
#          'our': 1,
#          'vocabulary': 1,
#          'the': 18,
#          'token': 2,
#          'parser': 2,
#          'is': 1,
#          'used': 1,
#          'to': 1,
#          'tokenize': 1,
#          'a': 4,
#          'test': 7,
#          'sentence': 2,
#          'just': 2,
#          'runs': 1,
#          'on': 2,
#          'data': 4,
#          'merges': 1,
#          'we': 4,
#          'have': 1,
#          'from': 1,
#          'training': 2,
#          'greedily': 1,
#          'in': 5,
#          'order': 1,
#          'them': 1,
#          'thus': 1,
#          'frequencies': 2,
#          'don’t': 1,
#          'play': 1,
#          'role': 1,
#          'so': 2,
#          'first': 2,
#          'segment': 1,
#          'each': 1,
#          'word': 4,
#          'into': 2,
#          'characters': 1,
#          'then': 2,
#          'apply': 1,
#          'rule': 2,
#          'replace': 2,
#          'every': 2,
#          'instance': 2,
#          'of': 2,
#          'er': 5,
#          'corpus': 3,
#          'with': 2,
#          'and': 2,
#          'second': 1,
#          '': 1,
#          'by': 1,
#          'end': 1,
#          'if': 1,
#          'contained': 1,
#          'newer': 1,
#          'it': 1,
#          'would': 2,
#          'be': 2,
#          'tokenized': 1,
#          'as': 1,
#          'full': 1,
#          'but': 1,
#          'new': 1,
#          'unknown': 1,
#          'like': 1,
#          'lower': 1,
#          'merged': 1,
#          'two': 1,
#          'tokens': 1,
#          'low': 1})

# %%
v_to_freq = [(corpus_vocab[k], list(k) + ['_']) for k in corpus_vocab]

# %%
v_to_freq[0]
# Out:
# (1, ['o', 'n', 'c', 'e', '_'])

# %%
def initialize_vocabulary(v_to_freq, vocabulary):
    for fr, syms in v_to_freq:
        for s in syms:
            if not s in vocabulary:
                vocabulary.append(s)
    return vocabulary
                
def find_frequent_pairs(v_to_freq):
    by_counter = Counter()
    for fr, syms in v_to_freq:
        bygrams = [tuple(syms[i:i+2]) for i in range(len(syms) - 1)]
        for b in bygrams:
            by_counter[b] += fr
    return by_counter.most_common(1)[0]

def merge_most_common(v_to_freq, mc_pair):
    new_sym = ''.join(mc_pair[0])
    new_v_to_freq = []
    for fr, syms in v_to_freq:
        if mc_pair[0] in [tuple(syms[i:i+2]) for i in range(len(syms) - 1)]:
            sym_parts = ''.join(syms).split(new_sym)
            syms_new = []
            for i in range(len(sym_parts) - 1):
                syms_new.extend(sym_parts[i])
                syms_new.append(new_sym)
            syms_new.extend(sym_parts[-1])
            new_v_to_freq.append((fr, syms_new))
        else:
            new_v_to_freq.append((fr, syms))
    return new_v_to_freq

# %%
bc = find_frequent_pairs(v_to_freq)

# %%
bc
# Out:
# (('e', '_'), 38)

# %%
res = merge_most_common(v_to_freq, bc)

# %%
res
# Out:
# [(1, ['o', 'n', 'c', 'e_']),
#  (1, ['w', 'e', '’', 'v', 'e_']),
#  (3, ['l', 'e', 'a', 'r', 'n', 'e', 'd', '_']),
#  (1, ['o', 'u', 'r', '_']),
#  (1, ['v', 'o', 'c', 'a', 'b', 'u', 'l', 'a', 'r', 'y', '_']),
#  (18, ['t', 'h', 'e_']),
#  (2, ['t', 'o', 'k', 'e', 'n', '_']),
#  (2, ['p', 'a', 'r', 's', 'e', 'r', '_']),
#  (1, ['i', 's', '_']),
#  (1, ['u', 's', 'e', 'd', '_']),
#  (1, ['t', 'o', '_']),
#  (1, ['t', 'o', 'k', 'e', 'n', 'i', 'z', 'e_']),
#  (4, ['a', '_']),
#  (7, ['t', 'e', 's', 't', '_']),
#  (2, ['s', 'e', 'n', 't', 'e', 'n', 'c', 'e_']),
#  (2, ['j', 'u', 's', 't', '_']),
#  (1, ['r', 'u', 'n', 's', '_']),
#  (2, ['o', 'n', '_']),
#  (4, ['d', 'a', 't', 'a', '_']),
#  (1, ['m', 'e', 'r', 'g', 'e', 's', '_']),
#  (4, ['w', 'e_']),
#  (1, ['h', 'a', 'v', 'e_']),
#  (1, ['f', 'r', 'o', 'm', '_']),
#  (2, ['t', 'r', 'a', 'i', 'n', 'i', 'n', 'g', '_']),
#  (1, ['g', 'r', 'e', 'e', 'd', 'i', 'l', 'y', '_']),
#  (5, ['i', 'n', '_']),
#  (1, ['o', 'r', 'd', 'e', 'r', '_']),
#  (1, ['t', 'h', 'e', 'm', '_']),
#  (1, ['t', 'h', 'u', 's', '_']),
#  (2, ['f', 'r', 'e', 'q', 'u', 'e', 'n', 'c', 'i', 'e', 's', '_']),
#  (1, ['d', 'o', 'n', '’', 't', '_']),
#  (1, ['p', 'l', 'a', 'y', '_']),
#  (1, ['r', 'o', 'l', 'e_']),
#  (2, ['s', 'o', '_']),
#  (2, ['f', 'i', 'r', 's', 't', '_']),
#  (1, ['s', 'e', 'g', 'm', 'e', 'n', 't', '_']),
#  (1, ['e', 'a', 'c', 'h', '_']),
#  (4, ['w', 'o', 'r', 'd', '_']),
#  (2, ['i', 'n', 't', 'o', '_']),
#  (1, ['c', 'h', 'a', 'r', 'a', 'c', 't', 'e', 'r', 's', '_']),
#  (2, ['t', 'h', 'e', 'n', '_']),
#  (1, ['a', 'p', 'p', 'l', 'y', '_']),
#  (2, ['r', 'u', 'l', 'e_']),
#  (2, ['r', 'e', 'p', 'l', 'a', 'c', 'e_']),
#  (2, ['e', 'v', 'e', 'r', 'y', '_']),
#  (2, ['i', 'n', 's', 't', 'a', 'n', 'c', 'e_']),
#  (2, ['o', 'f', '_']),
#  (5, ['e', 'r', '_']),
#  (3, ['c', 'o', 'r', 'p', 'u', 's', '_']),
#  (2, ['w', 'i', 't', 'h', '_']),
#  (2, ['a', 'n', 'd', '_']),
#  (1, ['s', 'e', 'c', 'o', 'n', 'd', '_']),
#  (1, ['_']),
#  (1, ['b', 'y', '_']),
#  (1, ['e', 'n', 'd', '_']),
#  (1, ['i', 'f', '_']),
#  (1, ['c', 'o', 'n', 't', 'a', 'i', 'n', 'e', 'd', '_']),
#  (1, ['n', 'e', 'w', 'e', 'r', '_']),
#  (1, ['i', 't', '_']),
#  (2, ['w', 'o', 'u', 'l', 'd', '_']),
#  (2, ['b', 'e_']),
#  (1, ['t', 'o', 'k', 'e', 'n', 'i', 'z', 'e', 'd', '_']),
#  (1, ['a', 's', '_']),
#  (1, ['f', 'u', 'l', 'l', '_']),
#  (1, ['b', 'u', 't', '_']),
#  (1, ['n', 'e', 'w', '_']),
#  (1, ['u', 'n', 'k', 'n', 'o', 'w', 'n', '_']),
#  (1, ['l', 'i', 'k', 'e_']),
#  (1, ['l', 'o', 'w', 'e', 'r', '_']),
#  (1, ['m', 'e', 'r', 'g', 'e', 'd', '_']),
#  (1, ['t', 'w', 'o', '_']),
#  (1, ['t', 'o', 'k', 'e', 'n', 's', '_']),
#  (1, ['l', 'o', 'w', '_'])]

# %%
vocab = initialize_vocabulary(v_to_freq, [])
used_vtf = v_to_freq.copy()

for i in range(25):
    next_pair = find_frequent_pairs(used_vtf)
    vocab.append(''.join(next_pair[0]))
    used_vtf = merge_most_common(used_vtf, next_pair)

# %%
used_vtf != v_to_freq
# Out:
# True

# %%
vocab
# Out:
# ['o',
#  'n',
#  'c',
#  'e',
#  '_',
#  'w',
#  '’',
#  'v',
#  'l',
#  'a',
#  'r',
#  'd',
#  'u',
#  'b',
#  'y',
#  't',
#  'h',
#  'k',
#  'p',
#  's',
#  'i',
#  'z',
#  'j',
#  'm',
#  'g',
#  'f',
#  'q',
#  'e_',
#  'th',
#  'the',
#  'the_',
#  'd_',
#  'er',
#  't_',
#  'in',
#  'en',
#  's_',
#  'st_',
#  'er_',
#  'to',
#  'a_',
#  'te',
#  'st',
#  'or',
#  'd_',
#  'en',
#  'ar',
#  'te',
#  't_',
#  'es',
#  'y_',
#  'er']

# %% [markdown]
# **Вывод:** получилось любопытно. За 25 итераций даже нашелся определенный артикль
